# %%
# !pip install torchviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from torchviz) (1.12.1+cu113)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.8/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->torchviz) (4.1.1)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4151 sha256=7308b463f29afe1cd986e2e9390b2740e4b7b0f2a0e7c0645433b6500a02fcac
#   Stored in directory: /root/.cache/pip/wheels/05/7d/1b/8306781244e42ede119edbb053bdcda1c1f424ca226165a417
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %%
import os
import pickle
import datetime

from collections import defaultdict

import matplotlib.pyplot as plt
from matplotlib import cm

import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
import dill
import json

import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose

import google.colab
from google.colab import files

import time

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## 1: Cargando los datos

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor()
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
trainset = datasets.FashionMNIST('MNIST_data/', download = True, train = True, transform = transform)
testset = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
labels_names = {
    0: "T-Shirt",    # Remera manga corta
    1: "Trouser",    # Pantalon
    2: "Pullover",   # Buzo
    3: "Dress",      # Vestido
    4: "Coat",       # Abrigo
    5: "Sandal",     # Sandalia
    6: "Shirt",      # Remera manga larga
    7: "Sneaker",    # Zapatilla
    8: "Bag",        # Bolso
    9: "Ankle Boot", # Bota
}

# %%
# Visualizamos las figuras
figure = plt.figure()
cols,rows = 3,3
for i in range(1,cols*rows+1):
    j = torch.randint(len(trainset),size=(1,)).item() # Los números aleatorios tambien se pueden generar desde pytorch. Util para trabajar en la GPU.
    image,label = trainset[j]
    figure.add_subplot(rows,cols,i)
    plt.title(labels_names[label])
    plt.axis("off")
    plt.imshow(image.squeeze(),cmap="Greys_r")
plt.show()

# %% [markdown]
# ## 2: Creando un `DataSet` personalizado.

# %%
# Creamos una subclase de Dataset que nos sirva para muestrear imagenes en el entrenamiento del autoencoder
class CustomDataset(Dataset):
    def __init__(self,dataset):
        self.dataset=dataset
    # Redefinimos el método .__len__()
    def __len__(self):
        return len(self.dataset)
    # Redefinimos el método .__getitem__()
    def __getitem__(self,i):
        image,label=self.dataset[i]
        label=torch.flatten(image) # Reescribimos el label original con una version achatada de la imagen.
        return image,label

# %%
# Convertimos FashionMNIST Dataset a CustomDataset para 
trainset = CustomDataset(trainset)
testset = CustomDataset(testset)

# %% [markdown]
# ## 3: Creando el Autoencoder

# %%
class Autoencoder(nn.Module):
    def __init__(self,n, p=0.1):
        super(Autoencoder, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28,n),
            nn.Dropout(p),
            nn.ReLU(),
            nn.Linear(n,28*28),
            nn.Dropout(p),
            nn.ReLU(),
        )
    def forward(self, x):
        x = self.flatten(x)
        return self.linear_relu_stack(x)

# %% [markdown]
# ## 3': Predicción vs imagen real ANTES de entrenar la red

# %%
n = 64
model = Autoencoder(n)

# Miramos que imagenes predice el modelo sin entrenar
figure = plt.figure()
rows,cols = 3,2
i = 0 # subplot index
for row in range(1,rows+1):
    j = torch.randint(len(trainset),size=(1,)).item() # Los números aleatorios tambien se pueden generar desde pytorch. Util para trabajar en la GPU.
    # Ploteamos la imagen original
    i += 1
    image,flatten_imagen = trainset[j]
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("original")
    plt.axis("off")
    plt.imshow(image.squeeze(),cmap="Greys_r")
    # Ploteamos la imagen predicha
    i += 1
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("predicha")
    plt.axis("off")
    #image_pred = model.imagen(image)
    image_gpu = image.to(device)
    pred_gpu = model(image_gpu)
    pred_cpu = pred_gpu.detach().cpu().numpy().reshape((1,28,28)).squeeze()
    plt.imshow(pred_cpu,cmap="Greys_r")
plt.show()

# %% [markdown]
# ## 4: Entrenando el modelo

# %%
# Definimos la función de entrenamiento
def train_loop(dataloader,model,loss_fn,optimizer):
    # Definimos ciertas constantes
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    sum_train_loss = 0
    # Movemos el modelo a la GPU
    model = model.to(device)
    # Seteamos el modelo en modo entrenamiento. Esto sirve para activar, por ejemplo, dropout, etc. durante la fase de entrenamiento
    model.train()
    # Iteramos sobre lotes (batchs)
    for batch, (X, y) in enumerate(dataloader):
        # Movemos el lote a la GPU
        X = X.to(device)
        y = y.to(device)
        # Calculamos la predicción del modelo y la correspondiente pérdida (error)
        pred = model(X)
        loss = loss_fn(pred,y)
        # Backpropagamos usando el optimizador proveido.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Imprimimos el progreso...
        loss_batch = loss.item()
        sum_train_loss += loss_batch
        if batch*batch_size % 5000 == 0:
            current = batch*len(X)
            print(f"batch={batch} loss={loss:>7f}  muestras-procesadas:[{current:>5d}/{size:>5d}]")
    avg_train_loss = sum_train_loss/num_batches
    return avg_train_loss

# De manera similar, definimos la función de testeo
def test_loop(dataloader,model,loss_fn):
    # Definimos ciertas constantes  
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    sum_test_loss,sum_correct = 0,0
    # Movemos el modelo a la GPU
    model = model.to(device)
    # Seteamos el modelo en modo evaluacion. Esto sirve para desactivar, por ejemplo, dropout, etc. cuando no estamos en una fase de entrenamiento.
    model.eval()
    # Para testear, desactivamos el cálculo de gradientes.
    with torch.no_grad():
        # Iteramos sobre lotes (batches)
        for X,y in dataloader:
            # Movemos el lote a la GPU
            X,y = X.to(device),y.to(device)          
            # Calculamos las predicciones del modelo...
            pred = model(X)
            # y las correspondientes pérdidas (errores), los cuales vamos acumulando en un valor total.
            loss_batch = loss_fn(pred,y).item()
            sum_test_loss += loss_batch
            # También calculamos el número de predicciones correctas, y lo acumulamos en un total.
            # sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    # Calculamos la pérdida total y la fracción de clasificaciones correctas, y las imprimimos.
    avg_test_loss = sum_test_loss/num_batches
    # frac_correct = sum_correct/size
    # print(f"Test Error: \n Accuracy: {(100*frac_correct):>0.1f}%, Avg loss: {avg_test_loss:>8f} \n")
    print(f"Test Error: Avg loss: {avg_test_loss:>8f} \n")
    return avg_test_loss

# %%
# Definimos
learning_rate = 1
batch_size = 1000
# n = 64
# model = Autoencoder(n)

# %%
# Creamos los DataLoaders
trainloader = DataLoader(trainset, batch_size = batch_size, shuffle = True)
testloader = DataLoader(testset, batch_size = batch_size, shuffle = True)

# %%
def func(L):
    model = Autoencoder(L)
    trainloader = DataLoader(trainset, batch_size = batch_size, shuffle = True)
    testloader = DataLoader(testset, batch_size = batch_size, shuffle = True)
    #loss_fn = nn.CrossEntropyLoss()  # Para clasificación
    loss_fn = nn.MSELoss()            # Para autoencoder
    optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)                                            #SGD
    #optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,eps=1e-08,weight_decay=0,amsgrad=False)   #Adam
    num_epochs = 100
    list_avg_train_loss = []
    list_avg_test_train_loss = []
    list_avg_test_loss = []

    ####
    start = time.perf_counter()
    print("El tiempo está siendo calculado")
    ####

    print(f"L= {L}\n------------------------------------------")

    for epoch in range(num_epochs):
      print(f"Epoch {epoch+1}\n------------------------------------------")
      avg_train_loss = train_loop(trainloader,model,loss_fn,optimizer)  # error promedio a medida que va entrenando (este NO SE GRAFICA)
      avg_test_train_loss = test_loop(trainloader,model,loss_fn)        # error promedio una vez que ya entreno todas las epocas
      avg_test_loss = test_loop(testloader,model,loss_fn)               # error promedio luego de testear
      list_avg_train_loss.append(avg_train_loss)
      list_avg_test_train_loss.append(avg_test_train_loss)
      list_avg_test_loss.append(avg_test_loss)
    
    print("Done!")

    ####
    end = time.perf_counter()
    print("El tiempo de ejecución fue", end - start)
    print("")
    ####

    return list_avg_test_train_loss, list_avg_test_loss

# %%
L = [64,]

# %%
lists = [func(n) for n in L]
# Out:
# This time is being calculated
# L= 64
# -------------------------------
# Epoch 1
# -------------------------------
# batch=0 loss=0.187042  muestras-procesadas:[    0/60000]
# batch=5 loss=0.164050  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.152889  muestras-procesadas:[10000/60000]
# batch=15 loss=0.144591  muestras-procesadas:[15000/60000]
# batch=20 loss=0.146004  muestras-procesadas:[20000/60000]
# batch=25 loss=0.137694  muestras-procesadas:[25000/60000]
# batch=30 loss=0.136380  muestras-procesadas:[30000/60000]
# batch=35 loss=0.133219  muestras-procesadas:[35000/60000]
# batch=40 loss=0.124016  muestras-procesadas:[40000/60000]
# batch=45 loss=0.121188  muestras-procesadas:[45000/60000]
# batch=50 loss=0.119202  muestras-procesadas:[50000/60000]
# batch=55 loss=0.120779  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.103887
#
# Test Error: Avg loss: 0.103726
#
# Epoch 2
# -------------------------------
# batch=0 loss=0.116354  muestras-procesadas:[    0/60000]
# batch=5 loss=0.117120  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.118007  muestras-procesadas:[10000/60000]
# batch=15 loss=0.117089  muestras-procesadas:[15000/60000]
# batch=20 loss=0.112780  muestras-procesadas:[20000/60000]
# batch=25 loss=0.111388  muestras-procesadas:[25000/60000]
# batch=30 loss=0.115111  muestras-procesadas:[30000/60000]
# batch=35 loss=0.115589  muestras-procesadas:[35000/60000]
# batch=40 loss=0.111063  muestras-procesadas:[40000/60000]
# batch=45 loss=0.111383  muestras-procesadas:[45000/60000]
# batch=50 loss=0.107982  muestras-procesadas:[50000/60000]
# batch=55 loss=0.107840  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.092971
#
# Test Error: Avg loss: 0.092823
#
# Epoch 3
# -------------------------------
# batch=0 loss=0.108585  muestras-procesadas:[    0/60000]
# batch=5 loss=0.108009  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.107721  muestras-procesadas:[10000/60000]
# batch=15 loss=0.105313  muestras-procesadas:[15000/60000]
# batch=20 loss=0.105050  muestras-procesadas:[20000/60000]
# batch=25 loss=0.104613  muestras-procesadas:[25000/60000]
# batch=30 loss=0.103857  muestras-procesadas:[30000/60000]
# batch=35 loss=0.103534  muestras-procesadas:[35000/60000]
# batch=40 loss=0.101250  muestras-procesadas:[40000/60000]
# batch=45 loss=0.098919  muestras-procesadas:[45000/60000]
# batch=50 loss=0.103154  muestras-procesadas:[50000/60000]
# batch=55 loss=0.100430  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.084507
#
# Test Error: Avg loss: 0.084355
#
# Epoch 4
# -------------------------------
# batch=0 loss=0.098309  muestras-procesadas:[    0/60000]
# batch=5 loss=0.097625  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.099286  muestras-procesadas:[10000/60000]
# batch=15 loss=0.098247  muestras-procesadas:[15000/60000]
# batch=20 loss=0.100773  muestras-procesadas:[20000/60000]
# batch=25 loss=0.096862  muestras-procesadas:[25000/60000]
# batch=30 loss=0.098115  muestras-procesadas:[30000/60000]
# batch=35 loss=0.096435  muestras-procesadas:[35000/60000]
# batch=40 loss=0.096922  muestras-procesadas:[40000/60000]
# batch=45 loss=0.097437  muestras-procesadas:[45000/60000]
# batch=50 loss=0.096671  muestras-procesadas:[50000/60000]
# batch=55 loss=0.094913  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.078887
#
# Test Error: Avg loss: 0.078737
#
# Epoch 5
# -------------------------------
# batch=0 loss=0.095691  muestras-procesadas:[    0/60000]
# batch=5 loss=0.095810  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.092650  muestras-procesadas:[10000/60000]
# batch=15 loss=0.091688  muestras-procesadas:[15000/60000]
# batch=20 loss=0.093748  muestras-procesadas:[20000/60000]
# batch=25 loss=0.091429  muestras-procesadas:[25000/60000]
# batch=30 loss=0.091552  muestras-procesadas:[30000/60000]
# batch=35 loss=0.091534  muestras-procesadas:[35000/60000]
# batch=40 loss=0.093101  muestras-procesadas:[40000/60000]
# batch=45 loss=0.090352  muestras-procesadas:[45000/60000]
# batch=50 loss=0.089911  muestras-procesadas:[50000/60000]
# batch=55 loss=0.090218  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.073398
#
# Test Error: Avg loss: 0.073257
#
# Epoch 6
# -------------------------------
# batch=0 loss=0.088420  muestras-procesadas:[    0/60000]
# batch=5 loss=0.089425  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.087596  muestras-procesadas:[10000/60000]
# batch=15 loss=0.088504  muestras-procesadas:[15000/60000]
# batch=20 loss=0.088868  muestras-procesadas:[20000/60000]
# batch=25 loss=0.086273  muestras-procesadas:[25000/60000]
# batch=30 loss=0.089604  muestras-procesadas:[30000/60000]
# batch=35 loss=0.089020  muestras-procesadas:[35000/60000]
# batch=40 loss=0.088721  muestras-procesadas:[40000/60000]
# batch=45 loss=0.088558  muestras-procesadas:[45000/60000]
# batch=50 loss=0.086281  muestras-procesadas:[50000/60000]
# batch=55 loss=0.087090  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.070697
#
# Test Error: Avg loss: 0.070560
#
# Epoch 7
# -------------------------------
# batch=0 loss=0.085999  muestras-procesadas:[    0/60000]
# batch=5 loss=0.086765  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.087179  muestras-procesadas:[10000/60000]
# batch=15 loss=0.087368  muestras-procesadas:[15000/60000]
# batch=20 loss=0.085844  muestras-procesadas:[20000/60000]
# batch=25 loss=0.082796  muestras-procesadas:[25000/60000]
# batch=30 loss=0.087946  muestras-procesadas:[30000/60000]
# batch=35 loss=0.085347  muestras-procesadas:[35000/60000]
# batch=40 loss=0.086312  muestras-procesadas:[40000/60000]
# batch=45 loss=0.084059  muestras-procesadas:[45000/60000]
# batch=50 loss=0.083118  muestras-procesadas:[50000/60000]
# batch=55 loss=0.086419  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.070583
#
# Test Error: Avg loss: 0.070448
#
# Epoch 8
# -------------------------------
# batch=0 loss=0.086321  muestras-procesadas:[    0/60000]
# batch=5 loss=0.087539  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.086204  muestras-procesadas:[10000/60000]
# batch=15 loss=0.085616  muestras-procesadas:[15000/60000]
# batch=20 loss=0.083961  muestras-procesadas:[20000/60000]
# batch=25 loss=0.085186  muestras-procesadas:[25000/60000]
# batch=30 loss=0.085764  muestras-procesadas:[30000/60000]
# batch=35 loss=0.082920  muestras-procesadas:[35000/60000]
# batch=40 loss=0.083948  muestras-procesadas:[40000/60000]
# batch=45 loss=0.083455  muestras-procesadas:[45000/60000]
# batch=50 loss=0.082731  muestras-procesadas:[50000/60000]
# batch=55 loss=0.081536  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.067912
#
# Test Error: Avg loss: 0.067777
#
# Epoch 9
# -------------------------------
# batch=0 loss=0.082182  muestras-procesadas:[    0/60000]
# batch=5 loss=0.082621  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.083233  muestras-procesadas:[10000/60000]
# batch=15 loss=0.080832  muestras-procesadas:[15000/60000]
# batch=20 loss=0.078918  muestras-procesadas:[20000/60000]
# batch=25 loss=0.079294  muestras-procesadas:[25000/60000]
# batch=30 loss=0.078419  muestras-procesadas:[30000/60000]
# batch=35 loss=0.078621  muestras-procesadas:[35000/60000]
# batch=40 loss=0.080670  muestras-procesadas:[40000/60000]
# batch=45 loss=0.079787  muestras-procesadas:[45000/60000]
# batch=50 loss=0.078630  muestras-procesadas:[50000/60000]
# batch=55 loss=0.078312  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.064774
#
# Test Error: Avg loss: 0.064642
#
# Epoch 10
# -------------------------------
# batch=0 loss=0.079678  muestras-procesadas:[    0/60000]
# batch=5 loss=0.080796  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.079931  muestras-procesadas:[10000/60000]
# batch=15 loss=0.078647  muestras-procesadas:[15000/60000]
# batch=20 loss=0.082902  muestras-procesadas:[20000/60000]
# batch=25 loss=0.080630  muestras-procesadas:[25000/60000]
# batch=30 loss=0.080145  muestras-procesadas:[30000/60000]
# batch=35 loss=0.079226  muestras-procesadas:[35000/60000]
# batch=40 loss=0.081781  muestras-procesadas:[40000/60000]
# batch=45 loss=0.077451  muestras-procesadas:[45000/60000]
# batch=50 loss=0.076060  muestras-procesadas:[50000/60000]
# batch=55 loss=0.080601  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.061765
#
# Test Error: Avg loss: 0.061637
#
# Epoch 11
# -------------------------------
# batch=0 loss=0.078608  muestras-procesadas:[    0/60000]
# batch=5 loss=0.076614  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.077249  muestras-procesadas:[10000/60000]
# batch=15 loss=0.078307  muestras-procesadas:[15000/60000]
# batch=20 loss=0.075140  muestras-procesadas:[20000/60000]
# batch=25 loss=0.074641  muestras-procesadas:[25000/60000]
# batch=30 loss=0.079277  muestras-procesadas:[30000/60000]
# batch=35 loss=0.077708  muestras-procesadas:[35000/60000]
# batch=40 loss=0.077381  muestras-procesadas:[40000/60000]
# batch=45 loss=0.077619  muestras-procesadas:[45000/60000]
# batch=50 loss=0.078079  muestras-procesadas:[50000/60000]
# batch=55 loss=0.077991  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.064320
#
# Test Error: Avg loss: 0.064204
#
# Epoch 12
# -------------------------------
# batch=0 loss=0.076158  muestras-procesadas:[    0/60000]
# batch=5 loss=0.079822  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.079826  muestras-procesadas:[10000/60000]
# batch=15 loss=0.077551  muestras-procesadas:[15000/60000]
# batch=20 loss=0.077143  muestras-procesadas:[20000/60000]
# batch=25 loss=0.073818  muestras-procesadas:[25000/60000]
# batch=30 loss=0.074249  muestras-procesadas:[30000/60000]
# batch=35 loss=0.072657  muestras-procesadas:[35000/60000]
# batch=40 loss=0.072404  muestras-procesadas:[40000/60000]
# batch=45 loss=0.075054  muestras-procesadas:[45000/60000]
# batch=50 loss=0.074176  muestras-procesadas:[50000/60000]
# batch=55 loss=0.072766  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.057453
#
# Test Error: Avg loss: 0.057328
#
# Epoch 13
# -------------------------------
# batch=0 loss=0.074658  muestras-procesadas:[    0/60000]
# batch=5 loss=0.073206  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.074569  muestras-procesadas:[10000/60000]
# batch=15 loss=0.074699  muestras-procesadas:[15000/60000]
# batch=20 loss=0.075525  muestras-procesadas:[20000/60000]
# batch=25 loss=0.073325  muestras-procesadas:[25000/60000]
# batch=30 loss=0.075474  muestras-procesadas:[30000/60000]
# batch=35 loss=0.074604  muestras-procesadas:[35000/60000]
# batch=40 loss=0.075628  muestras-procesadas:[40000/60000]
# batch=45 loss=0.074244  muestras-procesadas:[45000/60000]
# batch=50 loss=0.074312  muestras-procesadas:[50000/60000]
# batch=55 loss=0.074183  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.058133
#
# Test Error: Avg loss: 0.058012
#
# Epoch 14
# -------------------------------
# batch=0 loss=0.072486  muestras-procesadas:[    0/60000]
# batch=5 loss=0.071257  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.073334  muestras-procesadas:[10000/60000]
# batch=15 loss=0.073209  muestras-procesadas:[15000/60000]
# batch=20 loss=0.073377  muestras-procesadas:[20000/60000]
# batch=25 loss=0.071825  muestras-procesadas:[25000/60000]
# batch=30 loss=0.071968  muestras-procesadas:[30000/60000]
# batch=35 loss=0.070447  muestras-procesadas:[35000/60000]
# batch=40 loss=0.071393  muestras-procesadas:[40000/60000]
# batch=45 loss=0.071830  muestras-procesadas:[45000/60000]
# batch=50 loss=0.070210  muestras-procesadas:[50000/60000]
# batch=55 loss=0.072620  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.056961
#
# Test Error: Avg loss: 0.056849
#
# Epoch 15
# -------------------------------
# batch=0 loss=0.072147  muestras-procesadas:[    0/60000]
# batch=5 loss=0.072313  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.072826  muestras-procesadas:[10000/60000]
# batch=15 loss=0.072553  muestras-procesadas:[15000/60000]
# batch=20 loss=0.071018  muestras-procesadas:[20000/60000]
# batch=25 loss=0.070705  muestras-procesadas:[25000/60000]
# batch=30 loss=0.073939  muestras-procesadas:[30000/60000]
# batch=35 loss=0.070317  muestras-procesadas:[35000/60000]
# batch=40 loss=0.072283  muestras-procesadas:[40000/60000]
# batch=45 loss=0.069803  muestras-procesadas:[45000/60000]
# batch=50 loss=0.067748  muestras-procesadas:[50000/60000]
# batch=55 loss=0.068356  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.055919
#
# Test Error: Avg loss: 0.055813
#
# Epoch 16
# -------------------------------
# batch=0 loss=0.070836  muestras-procesadas:[    0/60000]
# batch=5 loss=0.070300  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.072053  muestras-procesadas:[10000/60000]
# batch=15 loss=0.070359  muestras-procesadas:[15000/60000]
# batch=20 loss=0.068889  muestras-procesadas:[20000/60000]
# batch=25 loss=0.070483  muestras-procesadas:[25000/60000]
# batch=30 loss=0.069111  muestras-procesadas:[30000/60000]
# batch=35 loss=0.070903  muestras-procesadas:[35000/60000]
# batch=40 loss=0.068405  muestras-procesadas:[40000/60000]
# batch=45 loss=0.069619  muestras-procesadas:[45000/60000]
# batch=50 loss=0.071008  muestras-procesadas:[50000/60000]
# batch=55 loss=0.071789  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.058142
#
# Test Error: Avg loss: 0.058053
#
# Epoch 17
# -------------------------------
# batch=0 loss=0.072193  muestras-procesadas:[    0/60000]
# batch=5 loss=0.071317  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.071471  muestras-procesadas:[10000/60000]
# batch=15 loss=0.069819  muestras-procesadas:[15000/60000]
# batch=20 loss=0.071232  muestras-procesadas:[20000/60000]
# batch=25 loss=0.068891  muestras-procesadas:[25000/60000]
# batch=30 loss=0.069243  muestras-procesadas:[30000/60000]
# batch=35 loss=0.067489  muestras-procesadas:[35000/60000]
# batch=40 loss=0.068335  muestras-procesadas:[40000/60000]
# batch=45 loss=0.066248  muestras-procesadas:[45000/60000]
# batch=50 loss=0.068422  muestras-procesadas:[50000/60000]
# batch=55 loss=0.066852  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.051154
#
# Test Error: Avg loss: 0.051058
#
# Epoch 18
# -------------------------------
# batch=0 loss=0.066701  muestras-procesadas:[    0/60000]
# batch=5 loss=0.066331  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.068056  muestras-procesadas:[10000/60000]
# batch=15 loss=0.065916  muestras-procesadas:[15000/60000]
# batch=20 loss=0.065386  muestras-procesadas:[20000/60000]
# batch=25 loss=0.068492  muestras-procesadas:[25000/60000]
# batch=30 loss=0.068414  muestras-procesadas:[30000/60000]
# batch=35 loss=0.067883  muestras-procesadas:[35000/60000]
# batch=40 loss=0.068830  muestras-procesadas:[40000/60000]
# batch=45 loss=0.068282  muestras-procesadas:[45000/60000]
# batch=50 loss=0.069119  muestras-procesadas:[50000/60000]
# batch=55 loss=0.069393  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.053553
#
# Test Error: Avg loss: 0.053470
#
# Epoch 19
# -------------------------------
# batch=0 loss=0.068578  muestras-procesadas:[    0/60000]
# batch=5 loss=0.067637  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.067695  muestras-procesadas:[10000/60000]
# batch=15 loss=0.065150  muestras-procesadas:[15000/60000]
# batch=20 loss=0.066335  muestras-procesadas:[20000/60000]
# batch=25 loss=0.068506  muestras-procesadas:[25000/60000]
# batch=30 loss=0.066133  muestras-procesadas:[30000/60000]
# batch=35 loss=0.066998  muestras-procesadas:[35000/60000]
# batch=40 loss=0.066273  muestras-procesadas:[40000/60000]
# batch=45 loss=0.065921  muestras-procesadas:[45000/60000]
# batch=50 loss=0.067165  muestras-procesadas:[50000/60000]
# batch=55 loss=0.066572  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.050213
#
# Test Error: Avg loss: 0.050131
#
# Epoch 20
# -------------------------------
# batch=0 loss=0.066280  muestras-procesadas:[    0/60000]
# batch=5 loss=0.066430  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.064809  muestras-procesadas:[10000/60000]
# batch=15 loss=0.065905  muestras-procesadas:[15000/60000]
# batch=20 loss=0.066863  muestras-procesadas:[20000/60000]
# batch=25 loss=0.064600  muestras-procesadas:[25000/60000]
# batch=30 loss=0.063681  muestras-procesadas:[30000/60000]
# batch=35 loss=0.066715  muestras-procesadas:[35000/60000]
# batch=40 loss=0.066533  muestras-procesadas:[40000/60000]
# batch=45 loss=0.068021  muestras-procesadas:[45000/60000]
# batch=50 loss=0.068196  muestras-procesadas:[50000/60000]
# batch=55 loss=0.067822  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.052568
#
# Test Error: Avg loss: 0.052506
#
# Epoch 21
# -------------------------------
# batch=0 loss=0.068521  muestras-procesadas:[    0/60000]
# batch=5 loss=0.067050  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.067074  muestras-procesadas:[10000/60000]
# batch=15 loss=0.067171  muestras-procesadas:[15000/60000]
# batch=20 loss=0.064885  muestras-procesadas:[20000/60000]
# batch=25 loss=0.065489  muestras-procesadas:[25000/60000]
# batch=30 loss=0.065125  muestras-procesadas:[30000/60000]
# batch=35 loss=0.065435  muestras-procesadas:[35000/60000]
# batch=40 loss=0.065000  muestras-procesadas:[40000/60000]
# batch=45 loss=0.063957  muestras-procesadas:[45000/60000]
# batch=50 loss=0.064960  muestras-procesadas:[50000/60000]
# batch=55 loss=0.063757  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.045755
#
# Test Error: Avg loss: 0.045683
#
# Epoch 22
# -------------------------------
# batch=0 loss=0.063379  muestras-procesadas:[    0/60000]
# batch=5 loss=0.064817  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.064458  muestras-procesadas:[10000/60000]
# batch=15 loss=0.062837  muestras-procesadas:[15000/60000]
# batch=20 loss=0.062880  muestras-procesadas:[20000/60000]
# batch=25 loss=0.064970  muestras-procesadas:[25000/60000]
# batch=30 loss=0.066474  muestras-procesadas:[30000/60000]
# batch=35 loss=0.066241  muestras-procesadas:[35000/60000]
# batch=40 loss=0.063056  muestras-procesadas:[40000/60000]
# batch=45 loss=0.065448  muestras-procesadas:[45000/60000]
# batch=50 loss=0.066760  muestras-procesadas:[50000/60000]
# batch=55 loss=0.067221  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.052006
#
# Test Error: Avg loss: 0.051966
#
# Epoch 23
# -------------------------------
# batch=0 loss=0.064761  muestras-procesadas:[    0/60000]
# batch=5 loss=0.065913  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.062649  muestras-procesadas:[10000/60000]
# batch=15 loss=0.062850  muestras-procesadas:[15000/60000]
# batch=20 loss=0.061352  muestras-procesadas:[20000/60000]
# batch=25 loss=0.062592  muestras-procesadas:[25000/60000]
# batch=30 loss=0.062615  muestras-procesadas:[30000/60000]
# batch=35 loss=0.062846  muestras-procesadas:[35000/60000]
# batch=40 loss=0.061817  muestras-procesadas:[40000/60000]
# batch=45 loss=0.065128  muestras-procesadas:[45000/60000]
# batch=50 loss=0.063138  muestras-procesadas:[50000/60000]
# batch=55 loss=0.064179  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.045807
#
# Test Error: Avg loss: 0.045757
#
# Epoch 24
# -------------------------------
# batch=0 loss=0.060991  muestras-procesadas:[    0/60000]
# batch=5 loss=0.061554  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.062513  muestras-procesadas:[10000/60000]
# batch=15 loss=0.061865  muestras-procesadas:[15000/60000]
# batch=20 loss=0.061996  muestras-procesadas:[20000/60000]
# batch=25 loss=0.062396  muestras-procesadas:[25000/60000]
# batch=30 loss=0.062360  muestras-procesadas:[30000/60000]
# batch=35 loss=0.064167  muestras-procesadas:[35000/60000]
# batch=40 loss=0.062055  muestras-procesadas:[40000/60000]
# batch=45 loss=0.062245  muestras-procesadas:[45000/60000]
# batch=50 loss=0.063510  muestras-procesadas:[50000/60000]
# batch=55 loss=0.063293  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.046397
#
# Test Error: Avg loss: 0.046356
#
# Epoch 25
# -------------------------------
# batch=0 loss=0.063542  muestras-procesadas:[    0/60000]
# batch=5 loss=0.062425  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.063903  muestras-procesadas:[10000/60000]
# batch=15 loss=0.063190  muestras-procesadas:[15000/60000]
# batch=20 loss=0.062307  muestras-procesadas:[20000/60000]
# batch=25 loss=0.062221  muestras-procesadas:[25000/60000]
# batch=30 loss=0.062799  muestras-procesadas:[30000/60000]
# batch=35 loss=0.061022  muestras-procesadas:[35000/60000]
# batch=40 loss=0.061600  muestras-procesadas:[40000/60000]
# batch=45 loss=0.063260  muestras-procesadas:[45000/60000]
# batch=50 loss=0.061705  muestras-procesadas:[50000/60000]
# batch=55 loss=0.061021  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.045017
#
# Test Error: Avg loss: 0.044978
#
# Epoch 26
# -------------------------------
# batch=0 loss=0.061786  muestras-procesadas:[    0/60000]
# batch=5 loss=0.060836  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.061108  muestras-procesadas:[10000/60000]
# batch=15 loss=0.060439  muestras-procesadas:[15000/60000]
# batch=20 loss=0.061542  muestras-procesadas:[20000/60000]
# batch=25 loss=0.062982  muestras-procesadas:[25000/60000]
# batch=30 loss=0.060923  muestras-procesadas:[30000/60000]
# batch=35 loss=0.061593  muestras-procesadas:[35000/60000]
# batch=40 loss=0.060250  muestras-procesadas:[40000/60000]
# batch=45 loss=0.061610  muestras-procesadas:[45000/60000]
# batch=50 loss=0.059312  muestras-procesadas:[50000/60000]
# batch=55 loss=0.060504  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.044615
#
# Test Error: Avg loss: 0.044587
#
# Epoch 27
# -------------------------------
# batch=0 loss=0.060000  muestras-procesadas:[    0/60000]
# batch=5 loss=0.059403  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.058756  muestras-procesadas:[10000/60000]
# batch=15 loss=0.060713  muestras-procesadas:[15000/60000]
# batch=20 loss=0.061182  muestras-procesadas:[20000/60000]
# batch=25 loss=0.062053  muestras-procesadas:[25000/60000]
# batch=30 loss=0.062576  muestras-procesadas:[30000/60000]
# batch=35 loss=0.062275  muestras-procesadas:[35000/60000]
# batch=40 loss=0.060089  muestras-procesadas:[40000/60000]
# batch=45 loss=0.060488  muestras-procesadas:[45000/60000]
# batch=50 loss=0.063711  muestras-procesadas:[50000/60000]
# batch=55 loss=0.059030  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.045601
#
# Test Error: Avg loss: 0.045582
#
# Epoch 28
# -------------------------------
# batch=0 loss=0.060717  muestras-procesadas:[    0/60000]
# batch=5 loss=0.059782  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.059683  muestras-procesadas:[10000/60000]
# batch=15 loss=0.060675  muestras-procesadas:[15000/60000]
# batch=20 loss=0.061115  muestras-procesadas:[20000/60000]
# batch=25 loss=0.059017  muestras-procesadas:[25000/60000]
# batch=30 loss=0.061156  muestras-procesadas:[30000/60000]
# batch=35 loss=0.061104  muestras-procesadas:[35000/60000]
# batch=40 loss=0.063023  muestras-procesadas:[40000/60000]
# batch=45 loss=0.061042  muestras-procesadas:[45000/60000]
# batch=50 loss=0.059474  muestras-procesadas:[50000/60000]
# batch=55 loss=0.059403  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.042608
#
# Test Error: Avg loss: 0.042582
#
# Epoch 29
# -------------------------------
# batch=0 loss=0.060696  muestras-procesadas:[    0/60000]
# batch=5 loss=0.061065  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.060954  muestras-procesadas:[10000/60000]
# batch=15 loss=0.059782  muestras-procesadas:[15000/60000]
# batch=20 loss=0.060413  muestras-procesadas:[20000/60000]
# batch=25 loss=0.058212  muestras-procesadas:[25000/60000]
# batch=30 loss=0.059831  muestras-procesadas:[30000/60000]
# batch=35 loss=0.060653  muestras-procesadas:[35000/60000]
# batch=40 loss=0.059313  muestras-procesadas:[40000/60000]
# batch=45 loss=0.059101  muestras-procesadas:[45000/60000]
# batch=50 loss=0.060536  muestras-procesadas:[50000/60000]
# batch=55 loss=0.058903  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.042145
#
# Test Error: Avg loss: 0.042123
#
# Epoch 30
# -------------------------------
# batch=0 loss=0.058666  muestras-procesadas:[    0/60000]
# batch=5 loss=0.057722  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.058432  muestras-procesadas:[10000/60000]
# batch=15 loss=0.058844  muestras-procesadas:[15000/60000]
# batch=20 loss=0.058940  muestras-procesadas:[20000/60000]
# batch=25 loss=0.058887  muestras-procesadas:[25000/60000]
# batch=30 loss=0.059504  muestras-procesadas:[30000/60000]
# batch=35 loss=0.060949  muestras-procesadas:[35000/60000]
# batch=40 loss=0.059492  muestras-procesadas:[40000/60000]
# batch=45 loss=0.059911  muestras-procesadas:[45000/60000]
# batch=50 loss=0.062185  muestras-procesadas:[50000/60000]
# batch=55 loss=0.059657  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.043012
#
# Test Error: Avg loss: 0.043000
#
# Epoch 31
# -------------------------------
# batch=0 loss=0.058987  muestras-procesadas:[    0/60000]
# batch=5 loss=0.058055  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.059105  muestras-procesadas:[10000/60000]
# batch=15 loss=0.059554  muestras-procesadas:[15000/60000]
# batch=20 loss=0.057912  muestras-procesadas:[20000/60000]
# batch=25 loss=0.058916  muestras-procesadas:[25000/60000]
# batch=30 loss=0.058705  muestras-procesadas:[30000/60000]
# batch=35 loss=0.058731  muestras-procesadas:[35000/60000]
# batch=40 loss=0.059044  muestras-procesadas:[40000/60000]
# batch=45 loss=0.059325  muestras-procesadas:[45000/60000]
# batch=50 loss=0.057343  muestras-procesadas:[50000/60000]
# batch=55 loss=0.058506  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.040116
#
# Test Error: Avg loss: 0.040096
#
# Epoch 32
# -------------------------------
# batch=0 loss=0.059651  muestras-procesadas:[    0/60000]
# batch=5 loss=0.058887  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.057871  muestras-procesadas:[10000/60000]
# batch=15 loss=0.058084  muestras-procesadas:[15000/60000]
# batch=20 loss=0.058015  muestras-procesadas:[20000/60000]
# batch=25 loss=0.057882  muestras-procesadas:[25000/60000]
# batch=30 loss=0.056224  muestras-procesadas:[30000/60000]
# batch=35 loss=0.057205  muestras-procesadas:[35000/60000]
# batch=40 loss=0.057236  muestras-procesadas:[40000/60000]
# batch=45 loss=0.057440  muestras-procesadas:[45000/60000]
# batch=50 loss=0.058505  muestras-procesadas:[50000/60000]
# batch=55 loss=0.057394  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.042354
#
# Test Error: Avg loss: 0.042349
#
# Epoch 33
# -------------------------------
# batch=0 loss=0.059121  muestras-procesadas:[    0/60000]
# batch=5 loss=0.057418  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.059709  muestras-procesadas:[10000/60000]
# batch=15 loss=0.060345  muestras-procesadas:[15000/60000]
# batch=20 loss=0.059969  muestras-procesadas:[20000/60000]
# batch=25 loss=0.057683  muestras-procesadas:[25000/60000]
# batch=30 loss=0.057276  muestras-procesadas:[30000/60000]
# batch=35 loss=0.058283  muestras-procesadas:[35000/60000]
# batch=40 loss=0.057163  muestras-procesadas:[40000/60000]
# batch=45 loss=0.059262  muestras-procesadas:[45000/60000]
# batch=50 loss=0.058737  muestras-procesadas:[50000/60000]
# batch=55 loss=0.058921  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.041376
#
# Test Error: Avg loss: 0.041369
#
# Epoch 34
# -------------------------------
# batch=0 loss=0.057377  muestras-procesadas:[    0/60000]
# batch=5 loss=0.056523  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.057462  muestras-procesadas:[10000/60000]
# batch=15 loss=0.056335  muestras-procesadas:[15000/60000]
# batch=20 loss=0.056969  muestras-procesadas:[20000/60000]
# batch=25 loss=0.056415  muestras-procesadas:[25000/60000]
# batch=30 loss=0.057455  muestras-procesadas:[30000/60000]
# batch=35 loss=0.057227  muestras-procesadas:[35000/60000]
# batch=40 loss=0.058254  muestras-procesadas:[40000/60000]
# batch=45 loss=0.055770  muestras-procesadas:[45000/60000]
# batch=50 loss=0.058345  muestras-procesadas:[50000/60000]
# batch=55 loss=0.057312  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.042231
#
# Test Error: Avg loss: 0.042232
#
# Epoch 35
# -------------------------------
# batch=0 loss=0.057899  muestras-procesadas:[    0/60000]
# batch=5 loss=0.059395  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.059818  muestras-procesadas:[10000/60000]
# batch=15 loss=0.058095  muestras-procesadas:[15000/60000]
# batch=20 loss=0.057159  muestras-procesadas:[20000/60000]
# batch=25 loss=0.057168  muestras-procesadas:[25000/60000]
# batch=30 loss=0.058010  muestras-procesadas:[30000/60000]
# batch=35 loss=0.058138  muestras-procesadas:[35000/60000]
# batch=40 loss=0.058047  muestras-procesadas:[40000/60000]
# batch=45 loss=0.057246  muestras-procesadas:[45000/60000]
# batch=50 loss=0.058134  muestras-procesadas:[50000/60000]
# batch=55 loss=0.056276  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.039814
#
# Test Error: Avg loss: 0.039807
#
# Epoch 36
# -------------------------------
# batch=0 loss=0.056699  muestras-procesadas:[    0/60000]
# batch=5 loss=0.056407  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.057202  muestras-procesadas:[10000/60000]
# batch=15 loss=0.057040  muestras-procesadas:[15000/60000]
# batch=20 loss=0.057433  muestras-procesadas:[20000/60000]
# batch=25 loss=0.057925  muestras-procesadas:[25000/60000]
# batch=30 loss=0.056320  muestras-procesadas:[30000/60000]
# batch=35 loss=0.057172  muestras-procesadas:[35000/60000]
# batch=40 loss=0.056661  muestras-procesadas:[40000/60000]
# batch=45 loss=0.057249  muestras-procesadas:[45000/60000]
# batch=50 loss=0.056261  muestras-procesadas:[50000/60000]
# batch=55 loss=0.055506  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.037462
#
# Test Error: Avg loss: 0.037450
#
# Epoch 37
# -------------------------------
# batch=0 loss=0.056424  muestras-procesadas:[    0/60000]
# batch=5 loss=0.057269  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.056987  muestras-procesadas:[10000/60000]
# batch=15 loss=0.055664  muestras-procesadas:[15000/60000]
# batch=20 loss=0.056491  muestras-procesadas:[20000/60000]
# batch=25 loss=0.055720  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055863  muestras-procesadas:[30000/60000]
# batch=35 loss=0.055689  muestras-procesadas:[35000/60000]
# batch=40 loss=0.053866  muestras-procesadas:[40000/60000]
# batch=45 loss=0.056810  muestras-procesadas:[45000/60000]
# batch=50 loss=0.055469  muestras-procesadas:[50000/60000]
# batch=55 loss=0.056033  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.039738
#
# Test Error: Avg loss: 0.039740
#
# Epoch 38
# -------------------------------
# batch=0 loss=0.056916  muestras-procesadas:[    0/60000]
# batch=5 loss=0.053525  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.055877  muestras-procesadas:[10000/60000]
# batch=15 loss=0.056111  muestras-procesadas:[15000/60000]
# batch=20 loss=0.056278  muestras-procesadas:[20000/60000]
# batch=25 loss=0.057039  muestras-procesadas:[25000/60000]
# batch=30 loss=0.057171  muestras-procesadas:[30000/60000]
# batch=35 loss=0.054454  muestras-procesadas:[35000/60000]
# batch=40 loss=0.056009  muestras-procesadas:[40000/60000]
# batch=45 loss=0.055244  muestras-procesadas:[45000/60000]
# batch=50 loss=0.055946  muestras-procesadas:[50000/60000]
# batch=55 loss=0.056581  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.040588
#
# Test Error: Avg loss: 0.040600
#
# Epoch 39
# -------------------------------
# batch=0 loss=0.056374  muestras-procesadas:[    0/60000]
# batch=5 loss=0.055607  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.055263  muestras-procesadas:[10000/60000]
# batch=15 loss=0.055652  muestras-procesadas:[15000/60000]
# batch=20 loss=0.056919  muestras-procesadas:[20000/60000]
# batch=25 loss=0.056291  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055524  muestras-procesadas:[30000/60000]
# batch=35 loss=0.055302  muestras-procesadas:[35000/60000]
# batch=40 loss=0.055046  muestras-procesadas:[40000/60000]
# batch=45 loss=0.056538  muestras-procesadas:[45000/60000]
# batch=50 loss=0.055866  muestras-procesadas:[50000/60000]
# batch=55 loss=0.055729  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.036896
#
# Test Error: Avg loss: 0.036894
#
# Epoch 40
# -------------------------------
# batch=0 loss=0.055371  muestras-procesadas:[    0/60000]
# batch=5 loss=0.055412  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.055132  muestras-procesadas:[10000/60000]
# batch=15 loss=0.055789  muestras-procesadas:[15000/60000]
# batch=20 loss=0.055962  muestras-procesadas:[20000/60000]
# batch=25 loss=0.054487  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055482  muestras-procesadas:[30000/60000]
# batch=35 loss=0.055700  muestras-procesadas:[35000/60000]
# batch=40 loss=0.056506  muestras-procesadas:[40000/60000]
# batch=45 loss=0.056281  muestras-procesadas:[45000/60000]
# batch=50 loss=0.056153  muestras-procesadas:[50000/60000]
# batch=55 loss=0.056375  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.039934
#
# Test Error: Avg loss: 0.039951
#
# Epoch 41
# -------------------------------
# batch=0 loss=0.056982  muestras-procesadas:[    0/60000]
# batch=5 loss=0.056893  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.056053  muestras-procesadas:[10000/60000]
# batch=15 loss=0.054810  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053478  muestras-procesadas:[20000/60000]
# batch=25 loss=0.054375  muestras-procesadas:[25000/60000]
# batch=30 loss=0.054384  muestras-procesadas:[30000/60000]
# batch=35 loss=0.053538  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054096  muestras-procesadas:[40000/60000]
# batch=45 loss=0.053079  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054643  muestras-procesadas:[50000/60000]
# batch=55 loss=0.055974  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.036096
#
# Test Error: Avg loss: 0.036093
#
# Epoch 42
# -------------------------------
# batch=0 loss=0.054700  muestras-procesadas:[    0/60000]
# batch=5 loss=0.055208  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.054639  muestras-procesadas:[10000/60000]
# batch=15 loss=0.054420  muestras-procesadas:[15000/60000]
# batch=20 loss=0.054979  muestras-procesadas:[20000/60000]
# batch=25 loss=0.055593  muestras-procesadas:[25000/60000]
# batch=30 loss=0.054648  muestras-procesadas:[30000/60000]
# batch=35 loss=0.054524  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054791  muestras-procesadas:[40000/60000]
# batch=45 loss=0.052845  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054562  muestras-procesadas:[50000/60000]
# batch=55 loss=0.055481  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.041720
#
# Test Error: Avg loss: 0.041747
#
# Epoch 43
# -------------------------------
# batch=0 loss=0.058662  muestras-procesadas:[    0/60000]
# batch=5 loss=0.056470  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.056503  muestras-procesadas:[10000/60000]
# batch=15 loss=0.055574  muestras-procesadas:[15000/60000]
# batch=20 loss=0.056666  muestras-procesadas:[20000/60000]
# batch=25 loss=0.055211  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055593  muestras-procesadas:[30000/60000]
# batch=35 loss=0.055949  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054326  muestras-procesadas:[40000/60000]
# batch=45 loss=0.055622  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054180  muestras-procesadas:[50000/60000]
# batch=55 loss=0.053283  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.036186
#
# Test Error: Avg loss: 0.036186
#
# Epoch 44
# -------------------------------
# batch=0 loss=0.054135  muestras-procesadas:[    0/60000]
# batch=5 loss=0.053745  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.054557  muestras-procesadas:[10000/60000]
# batch=15 loss=0.053723  muestras-procesadas:[15000/60000]
# batch=20 loss=0.055992  muestras-procesadas:[20000/60000]
# batch=25 loss=0.056198  muestras-procesadas:[25000/60000]
# batch=30 loss=0.053283  muestras-procesadas:[30000/60000]
# batch=35 loss=0.054040  muestras-procesadas:[35000/60000]
# batch=40 loss=0.053943  muestras-procesadas:[40000/60000]
# batch=45 loss=0.054808  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054247  muestras-procesadas:[50000/60000]
# batch=55 loss=0.055204  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.037181
#
# Test Error: Avg loss: 0.037187
#
# Epoch 45
# -------------------------------
# batch=0 loss=0.054840  muestras-procesadas:[    0/60000]
# batch=5 loss=0.055983  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.054218  muestras-procesadas:[10000/60000]
# batch=15 loss=0.055092  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053276  muestras-procesadas:[20000/60000]
# batch=25 loss=0.054686  muestras-procesadas:[25000/60000]
# batch=30 loss=0.052945  muestras-procesadas:[30000/60000]
# batch=35 loss=0.052129  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054620  muestras-procesadas:[40000/60000]
# batch=45 loss=0.053860  muestras-procesadas:[45000/60000]
# batch=50 loss=0.055365  muestras-procesadas:[50000/60000]
# batch=55 loss=0.054554  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.038628
#
# Test Error: Avg loss: 0.038645
#
# Epoch 46
# -------------------------------
# batch=0 loss=0.054947  muestras-procesadas:[    0/60000]
# batch=5 loss=0.054821  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.057335  muestras-procesadas:[10000/60000]
# batch=15 loss=0.053856  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053502  muestras-procesadas:[20000/60000]
# batch=25 loss=0.052816  muestras-procesadas:[25000/60000]
# batch=30 loss=0.053143  muestras-procesadas:[30000/60000]
# batch=35 loss=0.054970  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054625  muestras-procesadas:[40000/60000]
# batch=45 loss=0.053038  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054203  muestras-procesadas:[50000/60000]
# batch=55 loss=0.053409  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.035292
#
# Test Error: Avg loss: 0.035292
#
# Epoch 47
# -------------------------------
# batch=0 loss=0.053489  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052990  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.053305  muestras-procesadas:[10000/60000]
# batch=15 loss=0.053454  muestras-procesadas:[15000/60000]
# batch=20 loss=0.054802  muestras-procesadas:[20000/60000]
# batch=25 loss=0.054256  muestras-procesadas:[25000/60000]
# batch=30 loss=0.054597  muestras-procesadas:[30000/60000]
# batch=35 loss=0.054043  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054683  muestras-procesadas:[40000/60000]
# batch=45 loss=0.051866  muestras-procesadas:[45000/60000]
# batch=50 loss=0.053119  muestras-procesadas:[50000/60000]
# batch=55 loss=0.054097  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.036264
#
# Test Error: Avg loss: 0.036272
#
# Epoch 48
# -------------------------------
# batch=0 loss=0.052949  muestras-procesadas:[    0/60000]
# batch=5 loss=0.053503  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.052473  muestras-procesadas:[10000/60000]
# batch=15 loss=0.054317  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052346  muestras-procesadas:[20000/60000]
# batch=25 loss=0.053849  muestras-procesadas:[25000/60000]
# batch=30 loss=0.054281  muestras-procesadas:[30000/60000]
# batch=35 loss=0.053141  muestras-procesadas:[35000/60000]
# batch=40 loss=0.052289  muestras-procesadas:[40000/60000]
# batch=45 loss=0.052327  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054328  muestras-procesadas:[50000/60000]
# batch=55 loss=0.053559  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.037165
#
# Test Error: Avg loss: 0.037181
#
# Epoch 49
# -------------------------------
# batch=0 loss=0.053876  muestras-procesadas:[    0/60000]
# batch=5 loss=0.053259  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.053755  muestras-procesadas:[10000/60000]
# batch=15 loss=0.052583  muestras-procesadas:[15000/60000]
# batch=20 loss=0.054188  muestras-procesadas:[20000/60000]
# batch=25 loss=0.053175  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055040  muestras-procesadas:[30000/60000]
# batch=35 loss=0.056265  muestras-procesadas:[35000/60000]
# batch=40 loss=0.054744  muestras-procesadas:[40000/60000]
# batch=45 loss=0.054610  muestras-procesadas:[45000/60000]
# batch=50 loss=0.054443  muestras-procesadas:[50000/60000]
# batch=55 loss=0.053486  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.034092
#
# Test Error: Avg loss: 0.034095
#
# Epoch 50
# -------------------------------
# batch=0 loss=0.052539  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052653  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.053852  muestras-procesadas:[10000/60000]
# batch=15 loss=0.053018  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052760  muestras-procesadas:[20000/60000]
# batch=25 loss=0.052948  muestras-procesadas:[25000/60000]
# batch=30 loss=0.052025  muestras-procesadas:[30000/60000]
# batch=35 loss=0.051911  muestras-procesadas:[35000/60000]
# batch=40 loss=0.051204  muestras-procesadas:[40000/60000]
# batch=45 loss=0.053818  muestras-procesadas:[45000/60000]
# batch=50 loss=0.052755  muestras-procesadas:[50000/60000]
# batch=55 loss=0.052456  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.033586
#
# Test Error: Avg loss: 0.033588
#
# Epoch 51
# -------------------------------
# batch=0 loss=0.052477  muestras-procesadas:[    0/60000]
# batch=5 loss=0.051091  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.052721  muestras-procesadas:[10000/60000]
# batch=15 loss=0.054256  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053013  muestras-procesadas:[20000/60000]
# batch=25 loss=0.053724  muestras-procesadas:[25000/60000]
# batch=30 loss=0.053341  muestras-procesadas:[30000/60000]
# batch=35 loss=0.052043  muestras-procesadas:[35000/60000]
# batch=40 loss=0.055107  muestras-procesadas:[40000/60000]
# batch=45 loss=0.054939  muestras-procesadas:[45000/60000]
# batch=50 loss=0.055173  muestras-procesadas:[50000/60000]
# batch=55 loss=0.054076  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.037046
#
# Test Error: Avg loss: 0.037072
#
# Epoch 52
# -------------------------------
# batch=0 loss=0.054594  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052467  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.052980  muestras-procesadas:[10000/60000]
# batch=15 loss=0.052989  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053131  muestras-procesadas:[20000/60000]
# batch=25 loss=0.053052  muestras-procesadas:[25000/60000]
# batch=30 loss=0.055101  muestras-procesadas:[30000/60000]
# batch=35 loss=0.052977  muestras-procesadas:[35000/60000]
# batch=40 loss=0.053171  muestras-procesadas:[40000/60000]
# batch=45 loss=0.052547  muestras-procesadas:[45000/60000]
# batch=50 loss=0.053486  muestras-procesadas:[50000/60000]
# batch=55 loss=0.051857  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.034391
#
# Test Error: Avg loss: 0.034403
#
# Epoch 53
# -------------------------------
# batch=0 loss=0.053945  muestras-procesadas:[    0/60000]
# batch=5 loss=0.051026  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.052551  muestras-procesadas:[10000/60000]
# batch=15 loss=0.052650  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052345  muestras-procesadas:[20000/60000]
# batch=25 loss=0.051219  muestras-procesadas:[25000/60000]
# batch=30 loss=0.051035  muestras-procesadas:[30000/60000]
# batch=35 loss=0.051444  muestras-procesadas:[35000/60000]
# batch=40 loss=0.051682  muestras-procesadas:[40000/60000]
# batch=45 loss=0.050838  muestras-procesadas:[45000/60000]
# batch=50 loss=0.052195  muestras-procesadas:[50000/60000]
# batch=55 loss=0.051945  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.031083
#
# Test Error: Avg loss: 0.031077
#
# Epoch 54
# -------------------------------
# batch=0 loss=0.052641  muestras-procesadas:[    0/60000]
# batch=5 loss=0.053043  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.053210  muestras-procesadas:[10000/60000]
# batch=15 loss=0.051941  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052577  muestras-procesadas:[20000/60000]
# batch=25 loss=0.052991  muestras-procesadas:[25000/60000]
# batch=30 loss=0.052199  muestras-procesadas:[30000/60000]
# batch=35 loss=0.052245  muestras-procesadas:[35000/60000]
# batch=40 loss=0.053205  muestras-procesadas:[40000/60000]
# batch=45 loss=0.053750  muestras-procesadas:[45000/60000]
# batch=50 loss=0.053314  muestras-procesadas:[50000/60000]
# batch=55 loss=0.053000  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.030205
#
# Test Error: Avg loss: 0.030198
#
# Epoch 55
# -------------------------------
# batch=0 loss=0.054042  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052277  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.050456  muestras-procesadas:[10000/60000]
# batch=15 loss=0.053245  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052354  muestras-procesadas:[20000/60000]
# batch=25 loss=0.052480  muestras-procesadas:[25000/60000]
# batch=30 loss=0.053255  muestras-procesadas:[30000/60000]
# batch=35 loss=0.051923  muestras-procesadas:[35000/60000]
# batch=40 loss=0.053806  muestras-procesadas:[40000/60000]
# batch=45 loss=0.052435  muestras-procesadas:[45000/60000]
# batch=50 loss=0.052203  muestras-procesadas:[50000/60000]
# batch=55 loss=0.051157  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.030812
#
# Test Error: Avg loss: 0.030811
#
# Epoch 56
# -------------------------------
# batch=0 loss=0.052290  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052207  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.051028  muestras-procesadas:[10000/60000]
# batch=15 loss=0.051361  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052924  muestras-procesadas:[20000/60000]
# batch=25 loss=0.050995  muestras-procesadas:[25000/60000]
# batch=30 loss=0.052069  muestras-procesadas:[30000/60000]
# batch=35 loss=0.051454  muestras-procesadas:[35000/60000]
# batch=40 loss=0.052429  muestras-procesadas:[40000/60000]
# batch=45 loss=0.054006  muestras-procesadas:[45000/60000]
# batch=50 loss=0.051064  muestras-procesadas:[50000/60000]
# batch=55 loss=0.050501  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029887
#
# Test Error: Avg loss: 0.029886
#
# Epoch 57
# -------------------------------
# batch=0 loss=0.051036  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052511  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.051858  muestras-procesadas:[10000/60000]
# batch=15 loss=0.052402  muestras-procesadas:[15000/60000]
# batch=20 loss=0.053204  muestras-procesadas:[20000/60000]
# batch=25 loss=0.051589  muestras-procesadas:[25000/60000]
# batch=30 loss=0.052180  muestras-procesadas:[30000/60000]
# batch=35 loss=0.050155  muestras-procesadas:[35000/60000]
# batch=40 loss=0.052285  muestras-procesadas:[40000/60000]
# batch=45 loss=0.051515  muestras-procesadas:[45000/60000]
# batch=50 loss=0.052316  muestras-procesadas:[50000/60000]
# batch=55 loss=0.052369  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029903
#
# Test Error: Avg loss: 0.029905
#
# Epoch 58
# -------------------------------
# batch=0 loss=0.052390  muestras-procesadas:[    0/60000]
# batch=5 loss=0.052599  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.050850  muestras-procesadas:[10000/60000]
# batch=15 loss=0.051151  muestras-procesadas:[15000/60000]
# batch=20 loss=0.052372  muestras-procesadas:[20000/60000]
# batch=25 loss=0.052553  muestras-procesadas:[25000/60000]
# batch=30 loss=0.050308  muestras-procesadas:[30000/60000]
# batch=35 loss=0.050648  muestras-procesadas:[35000/60000]
# batch=40 loss=0.050107  muestras-procesadas:[40000/60000]
# batch=45 loss=0.051384  muestras-procesadas:[45000/60000]
# batch=50 loss=0.051184  muestras-procesadas:[50000/60000]
# batch=55 loss=0.051584  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029610
#
# Test Error: Avg loss: 0.029614
#
# Epoch 59
# -------------------------------
# batch=0 loss=0.050326  muestras-procesadas:[    0/60000]
# batch=5 loss=0.050185  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.052171  muestras-procesadas:[10000/60000]
# batch=15 loss=0.051113  muestras-procesadas:[15000/60000]
# batch=20 loss=0.051378  muestras-procesadas:[20000/60000]
# batch=25 loss=0.051607  muestras-procesadas:[25000/60000]
# batch=30 loss=0.050045  muestras-procesadas:[30000/60000]
# batch=35 loss=0.050056  muestras-procesadas:[35000/60000]
# batch=40 loss=0.049767  muestras-procesadas:[40000/60000]
# batch=45 loss=0.051168  muestras-procesadas:[45000/60000]
# batch=50 loss=0.050008  muestras-procesadas:[50000/60000]
# batch=55 loss=0.050601  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029047
#
# Test Error: Avg loss: 0.029049
#
# Epoch 60
# -------------------------------
# batch=0 loss=0.051572  muestras-procesadas:[    0/60000]
# batch=5 loss=0.051442  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.050591  muestras-procesadas:[10000/60000]
# batch=15 loss=0.051676  muestras-procesadas:[15000/60000]
# batch=20 loss=0.049384  muestras-procesadas:[20000/60000]
# batch=25 loss=0.051050  muestras-procesadas:[25000/60000]
# batch=30 loss=0.049471  muestras-procesadas:[30000/60000]
# batch=35 loss=0.051065  muestras-procesadas:[35000/60000]
# batch=40 loss=0.051471  muestras-procesadas:[40000/60000]
# batch=45 loss=0.051414  muestras-procesadas:[45000/60000]
# batch=50 loss=0.051155  muestras-procesadas:[50000/60000]
# ...
# batch=5 loss=0.049583  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.047420  muestras-procesadas:[10000/60000]
# batch=15 loss=0.048630  muestras-procesadas:[15000/60000]
# batch=20 loss=0.048009  muestras-procesadas:[20000/60000]
# batch=25 loss=0.048442  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046795  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046807  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046229  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046890  muestras-procesadas:[45000/60000]
# batch=50 loss=0.048862  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047352  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.026359
#
# Test Error: Avg loss: 0.026370
#
# Epoch 82
# -------------------------------
# batch=0 loss=0.047026  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047631  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.047342  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046753  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046518  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047773  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046596  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047695  muestras-procesadas:[35000/60000]
# batch=40 loss=0.048226  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046518  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047571  muestras-procesadas:[50000/60000]
# batch=55 loss=0.045855  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027730
#
# Test Error: Avg loss: 0.027750
#
# Epoch 83
# -------------------------------
# batch=0 loss=0.047350  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047131  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046861  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046928  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046782  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046779  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046758  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046610  muestras-procesadas:[35000/60000]
# batch=40 loss=0.048011  muestras-procesadas:[40000/60000]
# batch=45 loss=0.047763  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047726  muestras-procesadas:[50000/60000]
# batch=55 loss=0.048407  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.025368
#
# Test Error: Avg loss: 0.025378
#
# Epoch 84
# -------------------------------
# batch=0 loss=0.047673  muestras-procesadas:[    0/60000]
# batch=5 loss=0.048855  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046836  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047896  muestras-procesadas:[15000/60000]
# batch=20 loss=0.048530  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046738  muestras-procesadas:[25000/60000]
# batch=30 loss=0.049881  muestras-procesadas:[30000/60000]
# batch=35 loss=0.048821  muestras-procesadas:[35000/60000]
# batch=40 loss=0.048421  muestras-procesadas:[40000/60000]
# batch=45 loss=0.049179  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047267  muestras-procesadas:[50000/60000]
# batch=55 loss=0.048691  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.025473
#
# Test Error: Avg loss: 0.025484
#
# Epoch 85
# -------------------------------
# batch=0 loss=0.047835  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047159  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046383  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047170  muestras-procesadas:[15000/60000]
# batch=20 loss=0.048557  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046128  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046699  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047623  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047166  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046227  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046860  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047515  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.026089
#
# Test Error: Avg loss: 0.026104
#
# Epoch 86
# -------------------------------
# batch=0 loss=0.046885  muestras-procesadas:[    0/60000]
# batch=5 loss=0.048066  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.048087  muestras-procesadas:[10000/60000]
# batch=15 loss=0.048565  muestras-procesadas:[15000/60000]
# batch=20 loss=0.047759  muestras-procesadas:[20000/60000]
# batch=25 loss=0.048662  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047894  muestras-procesadas:[30000/60000]
# batch=35 loss=0.049473  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046599  muestras-procesadas:[40000/60000]
# batch=45 loss=0.047141  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046840  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046728  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.026137
#
# Test Error: Avg loss: 0.026153
#
# Epoch 87
# -------------------------------
# batch=0 loss=0.046002  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047433  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046521  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047304  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046407  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047375  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047915  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047142  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047384  muestras-procesadas:[40000/60000]
# batch=45 loss=0.048178  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047021  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047846  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.031401
#
# Test Error: Avg loss: 0.031451
#
# Epoch 88
# -------------------------------
# batch=0 loss=0.048200  muestras-procesadas:[    0/60000]
# batch=5 loss=0.048377  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.049803  muestras-procesadas:[10000/60000]
# batch=15 loss=0.048414  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046195  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047134  muestras-procesadas:[25000/60000]
# batch=30 loss=0.048298  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046708  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047260  muestras-procesadas:[40000/60000]
# batch=45 loss=0.047976  muestras-procesadas:[45000/60000]
# batch=50 loss=0.045733  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046145  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027300
#
# Test Error: Avg loss: 0.027326
#
# Epoch 89
# -------------------------------
# batch=0 loss=0.046798  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047042  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.045599  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046658  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046951  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047124  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047646  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046860  muestras-procesadas:[35000/60000]
# batch=40 loss=0.045991  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046885  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047234  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047238  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027590
#
# Test Error: Avg loss: 0.027617
#
# Epoch 90
# -------------------------------
# batch=0 loss=0.047196  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046852  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046839  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046827  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046354  muestras-procesadas:[20000/60000]
# batch=25 loss=0.045218  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047100  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046250  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046221  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046536  muestras-procesadas:[45000/60000]
# batch=50 loss=0.045450  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047357  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029569
#
# Test Error: Avg loss: 0.029611
#
# Epoch 91
# -------------------------------
# batch=0 loss=0.047494  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046548  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046669  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047095  muestras-procesadas:[15000/60000]
# batch=20 loss=0.045826  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046713  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046084  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047000  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047458  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046199  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047524  muestras-procesadas:[50000/60000]
# batch=55 loss=0.044998  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.031376
#
# Test Error: Avg loss: 0.031433
#
# Epoch 92
# -------------------------------
# batch=0 loss=0.047774  muestras-procesadas:[    0/60000]
# batch=5 loss=0.048719  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.048115  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047341  muestras-procesadas:[15000/60000]
# batch=20 loss=0.048465  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047762  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046205  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046270  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046480  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046919  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046620  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047370  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029426
#
# Test Error: Avg loss: 0.029469
#
# Epoch 93
# -------------------------------
# batch=0 loss=0.048101  muestras-procesadas:[    0/60000]
# batch=5 loss=0.047696  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046895  muestras-procesadas:[10000/60000]
# batch=15 loss=0.048170  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046187  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047926  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047814  muestras-procesadas:[30000/60000]
# batch=35 loss=0.045658  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046305  muestras-procesadas:[40000/60000]
# batch=45 loss=0.047846  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046482  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047274  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.028625
#
# Test Error: Avg loss: 0.028663
#
# Epoch 94
# -------------------------------
# batch=0 loss=0.046897  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046697  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.047539  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046407  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046806  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047817  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047015  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047876  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047034  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046170  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047179  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046756  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.026999
#
# Test Error: Avg loss: 0.027028
#
# Epoch 95
# -------------------------------
# batch=0 loss=0.045811  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046475  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.047147  muestras-procesadas:[10000/60000]
# batch=15 loss=0.045304  muestras-procesadas:[15000/60000]
# batch=20 loss=0.045641  muestras-procesadas:[20000/60000]
# batch=25 loss=0.045855  muestras-procesadas:[25000/60000]
# batch=30 loss=0.045776  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047768  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047504  muestras-procesadas:[40000/60000]
# batch=45 loss=0.044509  muestras-procesadas:[45000/60000]
# batch=50 loss=0.045484  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046885  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027748
#
# Test Error: Avg loss: 0.027783
#
# Epoch 96
# -------------------------------
# batch=0 loss=0.046270  muestras-procesadas:[    0/60000]
# batch=5 loss=0.045989  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046659  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046339  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046870  muestras-procesadas:[20000/60000]
# batch=25 loss=0.045453  muestras-procesadas:[25000/60000]
# batch=30 loss=0.047242  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046674  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046462  muestras-procesadas:[40000/60000]
# batch=45 loss=0.045833  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046619  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046477  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027042
#
# Test Error: Avg loss: 0.027074
#
# Epoch 97
# -------------------------------
# batch=0 loss=0.046826  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046171  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046368  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046373  muestras-procesadas:[15000/60000]
# batch=20 loss=0.047481  muestras-procesadas:[20000/60000]
# batch=25 loss=0.047275  muestras-procesadas:[25000/60000]
# batch=30 loss=0.048469  muestras-procesadas:[30000/60000]
# batch=35 loss=0.047142  muestras-procesadas:[35000/60000]
# batch=40 loss=0.047344  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046447  muestras-procesadas:[45000/60000]
# batch=50 loss=0.047439  muestras-procesadas:[50000/60000]
# batch=55 loss=0.047972  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029407
#
# Test Error: Avg loss: 0.029456
#
# Epoch 98
# -------------------------------
# batch=0 loss=0.046446  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046739  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046386  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046882  muestras-procesadas:[15000/60000]
# batch=20 loss=0.047556  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046557  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046022  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046796  muestras-procesadas:[35000/60000]
# batch=40 loss=0.044428  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046057  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046091  muestras-procesadas:[50000/60000]
# batch=55 loss=0.045877  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.028402
#
# Test Error: Avg loss: 0.028441
#
# Epoch 99
# -------------------------------
# batch=0 loss=0.047567  muestras-procesadas:[    0/60000]
# batch=5 loss=0.045835  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.046895  muestras-procesadas:[10000/60000]
# batch=15 loss=0.047474  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046834  muestras-procesadas:[20000/60000]
# batch=25 loss=0.045852  muestras-procesadas:[25000/60000]
# batch=30 loss=0.045410  muestras-procesadas:[30000/60000]
# batch=35 loss=0.045330  muestras-procesadas:[35000/60000]
# batch=40 loss=0.045755  muestras-procesadas:[40000/60000]
# batch=45 loss=0.044863  muestras-procesadas:[45000/60000]
# batch=50 loss=0.045453  muestras-procesadas:[50000/60000]
# batch=55 loss=0.046836  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.027823
#
# Test Error: Avg loss: 0.027861
#
# Epoch 100
# -------------------------------
# batch=0 loss=0.044966  muestras-procesadas:[    0/60000]
# batch=5 loss=0.046029  muestras-procesadas:[ 5000/60000]
# batch=10 loss=0.045296  muestras-procesadas:[10000/60000]
# batch=15 loss=0.046071  muestras-procesadas:[15000/60000]
# batch=20 loss=0.046884  muestras-procesadas:[20000/60000]
# batch=25 loss=0.046030  muestras-procesadas:[25000/60000]
# batch=30 loss=0.046296  muestras-procesadas:[30000/60000]
# batch=35 loss=0.046607  muestras-procesadas:[35000/60000]
# batch=40 loss=0.046170  muestras-procesadas:[40000/60000]
# batch=45 loss=0.046651  muestras-procesadas:[45000/60000]
# batch=50 loss=0.046448  muestras-procesadas:[50000/60000]
# batch=55 loss=0.045975  muestras-procesadas:[55000/60000]
# Test Error: Avg loss: 0.029750
#
# Test Error: Avg loss: 0.029803
#
# Done!
# El tiempo de ejecución fue 1443.3064497029998

# %%
plt.xlabel('Épocas')
plt.ylabel('Error promedio')

plt.plot(list(range(1,len(lists[0][0])+1)),lists[0][0],label=f"train L={L[0]}",linestyle='-',linewidth=2.0,c='royalblue')
plt.plot(list(range(1,len(lists[0][0])+1)),lists[0][1],label=f"test L={L[0]}",linestyle=':',linewidth=3.0,c='darkorange')

plt.title('')
plt.legend()
plt.grid()
plt.savefig('fig:sgc-64-100_epocas.pdf', dpi=600, format='pdf')

# %% [markdown]
# ## 4': Predicción vs imagen real DESPUÉS de entrenar la red

# %%
# Miramos que imagenes predice el modelo entrenado
figure = plt.figure()
rows,cols = 3,2
i = 0 # subplot index
for row in range(1,rows+1):
    j = torch.randint(len(trainset),size=(1,)).item() # Los números aleatorios tambien se pueden generar desde pytorch. Util para trabajar en la GPU.
    # Ploteamos la imagen original
    i += 1
    image,flatten_imagen = trainset[j]
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("original")
    plt.axis("off")
    plt.imshow(image.squeeze(),cmap="Greys_r")
    # Ploteamos la imagen predicha
    i += 1
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("predicha")
    plt.axis("off")
    #image_pred = model.imagen(image)
    #plt.imshow(image_pred,cmap="Greys_r")
    with torch.no_grad(): # 
        image_gpu = image.to(device)
    pred_gpu = model(image_gpu)
    pred_cpu = pred_gpu.detach().cpu().numpy().reshape((1,28,28)).squeeze()
    plt.imshow(pred_cpu,cmap="Greys_r")    
plt.show()
